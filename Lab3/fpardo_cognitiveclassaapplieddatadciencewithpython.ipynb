# %% [markdown]
# <a href="https://colab.research.google.com/github/FranZixX/MetNumUN2023I/blob/main/Lab3/fpardo_cognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.linkedin.com/in/franzixx/details/certifications/
#
# ![FSPA.png](data:image/png;base64,...)

# %% [markdown]
# ![data visualization with python.png](data:image/png;base64,...)

# %% [markdown]
# ![data analysis with python.png](data:image/png;base64,...)

# %% [markdown]
# ![python101datascience.png](data:image/png;base64,...)
